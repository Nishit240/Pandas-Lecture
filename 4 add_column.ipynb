# %%
import pandas as pd

# %%
data = {
    "Name": ['Ram', 'Shyam', 'Ghanshyam', 'Dhanshyam', 'Aditi', 'Jagdish', 'Raj', 'Simran'],
    "Age": [28,34,22,30,29,40,25,32],
    "Salary": [50000,60000,45000,52000,49000, 70000,48000,58000],
    "Performance Score": [85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

# %%
df["Bonus"] = df["Salary"] + (df["Salary"] * 0.1)
print(df)
# Out:
#         Name  Age  Salary  Performance Score    Bonus
# 0        Ram   28   50000                 85  55000.0
# 1      Shyam   34   60000                 90  66000.0
# 2  Ghanshyam   22   45000                 78  49500.0
# 3  Dhanshyam   30   52000                 92  57200.0
# 4      Aditi   29   49000                 88  53900.0
# 5    Jagdish   40   70000                 95  77000.0
# 6        Raj   25   48000                 80  52800.0
# 7     Simran   32   58000                 89  63800.0

# %%
df.insert(0,"Empoloyee_ID", [1,2,3,4,5,6,7,8])

print(df)
# Out:
#    Empoloyee_ID       Name  Age  Salary  Performance Score    Bonus
# 0             1        Ram   28   50000                 85  55000.0
# 1             2      Shyam   34   60000                 90  66000.0
# 2             3  Ghanshyam   22   45000                 78  49500.0
# 3             4  Dhanshyam   30   52000                 92  57200.0
# 4             5      Aditi   29   49000                 88  53900.0
# 5             6    Jagdish   40   70000                 95  77000.0
# 6             7        Raj   25   48000                 80  52800.0
# 7             8     Simran   32   58000                 89  63800.0
