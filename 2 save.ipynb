# %%
import pandas as pd

# %%
data = {
    "Name" : ["Nishit", "Palak", "Rohan"],
    "Age" : [21, 22, 29],
    "Department" : ["IT", "CSE", "Finance"]
}

df = pd.DataFrame(data)
print(df)
# df.to_csv("save_csv.csv", index = False)

# pip install openpyxl
# df.to_excel("save_excel.xlsx", index = False)

# df.to_json("save_json.json")

# df.to_html("save_html.html" , index = False)
# Out:
#      Name  Age Department
# 0  Nishit   21         IT
# 1   Palak   22        CSE
# 2   Rohan   29    Finance

# %%
df = pd.read_csv("save_csv.csv", encoding = "utf-8")
print(df)

df = pd.read_json("save_json.json")
print(df)
# Out:
#           Day  Coffee Type   Units Sold
# 0      Monday     Espresso           25
# 1      Monday        Latte           15
# 2     Tuesday     Espresso           30
# 3     Tuesday        Latte           20
# 4   Wednesday     Espresso           35
# 5   Wednesday        Latte           25
# 6    Thursday     Espresso           40
# 7    Thursday        Latte           30
# 8      Friday     Espresso           45
# 9      Friday        Latte           35
# 10   Saturday     Espresso           45
# 11   Saturday        Latte           35
# 12     Sunday     Espresso           45
# 13     Sunday        Latte           35
#      Name  Age Department
# 0  Nishit   21         IT
# 1   Palak   22        CSE
# 2   Rohan   29    Finance

# %% [markdown]
# ### HEAD: head()
# ### TAIL: tail(n)

# %%
df = pd.read_csv("save_csv.csv", encoding = "utf-8")
print("display 5 rows of first ")
print(df.head(5))

print("")

print("display 5 rows of last ")
print(df.tail(5))
# Out:
# display 5 rows of first
#          Day  Coffee Type   Units Sold
# 0     Monday     Espresso           25
# 1     Monday        Latte           15
# 2    Tuesday     Espresso           30
# 3    Tuesday        Latte           20
# 4  Wednesday     Espresso           35
#
# display 5 rows of last
#          Day  Coffee Type   Units Sold
# 9     Friday        Latte           35
# 10  Saturday     Espresso           45
# 11  Saturday        Latte           35
# 12    Sunday     Espresso           45
# 13    Sunday        Latte           35

# %%
df = pd.read_csv("save_csv.csv", encoding = "utf-8")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Day           14 non-null     object
#  1    Coffee Type  14 non-null     object
#  2    Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes
# None

# %%
data = {
    "Name": ['Ram', 'Shyam', 'Ghanshyam', 'Dhanshyam', 'Aditi', 'Jagdish', 'Raj', 'Simran'],
    "Age": [28,34,22,30,29,40,25,32],
    "Salary": [50000,60000,45000,52000,49000, 70000,48000,58000],
    "Performance Score": [85,90,78,92,88,95,80,89]
}
df= pd.DataFrame(data)
print("Sample Dataframe")
print(df)
print("")
print('Descriptive Statistics')
print(df.describe())
# Out:
# Sample Dataframe
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
#
# Descriptive Statistics
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   30.000000  54000.000000          87.125000
# std     5.529144   8194.074514           5.817154
# min    22.000000  45000.000000          78.000000
# 25%    27.250000  48750.000000          83.750000
# 50%    29.500000  51000.000000          88.500000
# 75%    32.500000  58500.000000          90.500000
# max    40.000000  70000.000000          95.000000

# %%
print(df)
print(f"shape: {df.shape}")
print(f"column names: {df.columns}")
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89
# shape: (8, 4)
# column names: Index(['Name', 'Age', 'Salary', 'Performance Score'], dtype='object')

# %% [markdown]
# select specific coloum

# %%
print(df['Name'])

print(df[['Name', 'Salary']])
# Out:
# 0          Ram
# 1        Shyam
# 2    Ghanshyam
# 3    Dhanshyam
# 4        Aditi
# 5      Jagdish
# 6          Raj
# 7       Simran
# Name: Name, dtype: object
#         Name  Salary
# 0        Ram   50000
# 1      Shyam   60000
# 2  Ghanshyam   45000
# 3  Dhanshyam   52000
# 4      Aditi   49000
# 5    Jagdish   70000
# 6        Raj   48000
# 7     Simran   58000

# %% [markdown]
# Filter rows with single and multiple conditions

# %%
high_salary = df[df['Salary'] > 50000]
print(high_salary)

print("")
filter = df[(df['Salary'] > 50000) & (df['Performance Score'] >= 90)]
print(filter)


print("")
filter_or = df[(df['Age'] > 30) | (df['Performance Score'] >= 90)]
print(filter_or)
# Out:
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89
#
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
#
#         Name  Age  Salary  Performance Score
# 1      Shyam   34   60000                 90
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89
