# %%
import pandas as pd

# %%
data = {
    "Name": ['Ram', 'Shyam', 'Ghanshyam', 'Dhanshyam', 'Aditi', 'Jagdish', 'Raj', 'Simran'],
    "Age": [28,34,22,30,29,40,25,32],
    "Salary": [50000,60000,45000,52000,49000, 70000,48000,58000],
    "Performance Score": [85,90,78,92,88,95,80,89]
}

df = pd.DataFrame(data)
print(df)
# Out:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   34   60000                 90
# 2  Ghanshyam   22   45000                 78
# 3  Dhanshyam   30   52000                 92
# 4      Aditi   29   49000                 88
# 5    Jagdish   40   70000                 95
# 6        Raj   25   48000                 80
# 7     Simran   32   58000                 89

# %%
df.loc[0, 'Salary'] = 55000
print(df)
# Out:
#         Name  Age        Salary  Performance Score
# 0        Ram   28  55000.000000                 85
# 1      Shyam   34   5387.568978                 90
# 2  Ghanshyam   22   4040.676734                 78
# 3  Dhanshyam   30   4669.226448                 92
# 4      Aditi   29   4399.847999                 88
# 5    Jagdish   40   6285.497141                 95
# 6        Raj   25   4310.055182                 80
# 7     Simran   32   5207.983345                 89

# %%
df['Salary'] = df['Salary'] * 1.05
print(df)
# Out:
#         Name  Age        Salary  Performance Score
# 0        Ram   28  57750.000000                 85
# 1      Shyam   34   5656.947427                 90
# 2  Ghanshyam   22   4242.710570                 78
# 3  Dhanshyam   30   4902.687770                 92
# 4      Aditi   29   4619.840399                 88
# 5    Jagdish   40   6599.771998                 95
# 6        Raj   25   4525.557942                 80
# 7     Simran   32   5468.382513                 89
